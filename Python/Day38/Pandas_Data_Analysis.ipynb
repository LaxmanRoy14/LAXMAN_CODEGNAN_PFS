# %% [markdown]
# Pandas
# -------
# --> This pandas is used for handling structured data in table format

# %%
import pandas as pd

# %%
data = {"Name" : ["Teja", "Roy"], "Marks" : [35, 85]}
any = pd.DataFrame(data)
print(any)
# Out:
#    Name  Marks
# 0  Teja     35
# 1   Roy     85
