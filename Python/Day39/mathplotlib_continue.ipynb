# %%
import matplotlib.pyplot as plt

# %%
plt.pie([40, 15, 20, 35], labels)

# %%
plt.scatter([1, 2, 3, 4], [200, 400, 100, 800], color = "Yellow", s= 100)
plt.title("Swift Car Sales")
plt.xlabel("Years")
plt.ylabel("Number Of Sales")
plt.show()

# %%
plt.pie([40, 15, 35, 20], labels = ["Backend(Python)", "Frontend(HTML, CSS)", "Framework(Flask)", "Library(Numpy, Pandas, matplotlib)"])
plt.title("ATM Application(Project)")
plt.legend(["Laxman", "Roy", "Teja", "Bhanu"])
plt.show()
